# %% [markdown]
# Here we are going to analyze the sakila DB

# %%
import pandas as pd 
stats = pd.read_csv('D:\\POC\\Python\\Udemy_python_cource\\sakila_address.csv')

# %%
stats
# Out:
#      address_id                        address  address2             district  \
# 0             1              47 MySakila Drive       NaN              Alberta
# 1             2             28 MySQL Boulevard       NaN                  QLD
# 2             3              23 Workhaven Lane       NaN              Alberta
# 3             4           1411 Lillydale Drive       NaN                  QLD
# 4             5                 1913 Hanoi Way       NaN             Nagasaki
# ..          ...                            ...       ...                  ...
# 195         196   9 San Miguel de Tucumn Manor       NaN        Uttar Pradesh
# 196         197             447 Surakarta Loop       NaN               Nyanza
# 197         198           345 Oshawa Boulevard       NaN             Tokyo-to
# 198         199  1792 Valle de la Pascua Place       NaN  Nordrhein-Westfalen
# 199         200             1074 Binzhou Manor       NaN     Baden-Wrttemberg
#
# ...
